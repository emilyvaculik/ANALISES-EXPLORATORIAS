# %%
#VISUALIZAÇÃO DE DADOS

# %%
import pandas as pd

# %%
dados = pd.read_csv("/ARQUIVO SUS DATA DE PROCESSAMENTO.csv", encoding="ISO-8859-1",
            skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
# Out:
# <ipython-input-4-9686b82c33f8>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv("/ARQUIVO SUS DATA DE PROCESSAMENTO.csv", encoding="ISO-8859-1",

# %%
dados.head()
# Out:
#   Unidade da Federação  2008/Jan  2008/Fev  2008/Mar  2008/Abr  2008/Mai  \
# 0          11 Rondônia      4142      7301      4318      4285      4511
# 1              12 Acre      2087      3071      3783      3737      3609
# 2          13 Amazonas      9325     12807     14827     14606     12880
# 3           14 Roraima      1475      1812      1813      1964      2037
# 4              15 Pará     38628     41537     42832     41154     44685
#
#    2008/Jun  2008/Jul  2008/Ago  2008/Set  ...  2022/Dez  2023/Jan  2023/Fev  \
# 0      3871      7560      7615      7507  ...     10294      9645      9486
# 1      4026      4880      4250      4552  ...      4671      4165      4834
# 2     14120     15476     15708     15108  ...     17846     18118     15400
# 3      2030      2307      2153      1913  ...      4489      4734      3936
# 4     43548     45150     43701     44296  ...     41483     42516     41795
#
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação  2008/Jan  2008/Fev  2008/Mar  2008/Abr  2008/Mai  \
# 22   43 Rio Grande do Sul     41729     64759     61553     64452     57030
# 23  50 Mato Grosso do Sul      9636     11323     12093     12705     13212
# 24         51 Mato Grosso      9975     14381     14226     14946     14725
# 25               52 Goiás     26465     35549     33115     33963     33713
# 26    53 Distrito Federal      7754     12057     14746     14759     16769
#
#     2008/Jun  2008/Jul  2008/Ago  2008/Set  ...  2022/Dez  2023/Jan  2023/Fev  \
# 22     58637     64650     63736     61539  ...     66871     64773     60068
# 23     14611     13770     13427     14128  ...     15868     16406     16464
# 24     16518     15560     15505     14207  ...     17238     16641     17535
# 25     28746     31687     31746     33019  ...     31844     34475     32789
# 26     17922     17780     18938     16225  ...     17344     18394     17791
#
# ...

# %%
dados.mean()
# Out:
# <ipython-input-7-99af3ba13e28>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.mean()
# 2008/Jan    2.413389e+04
# 2008/Fev    3.163441e+04
# 2008/Mar    3.416119e+04
# 2008/Abr    3.516478e+04
# 2008/Mai    3.623100e+04
#                 ...
# 2023/Mai    4.238959e+04
# 2023/Jun    4.134822e+04
# 2023/Jul    4.119541e+04
# 2023/Ago    4.011337e+04
# Total       6.789884e+06
# Length: 188, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 190 entries, Unidade da Federação to Total
# dtypes: int64(188), object(2)
# memory usage: 40.2+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# <ipython-input-10-99af3ba13e28>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.mean()
# 2008/Jan     24133.89
# 2008/Fev     31634.41
# 2008/Mar     34161.19
# 2008/Abr     35164.78
# 2008/Mai     36231.00
#               ...
# 2023/Mai     42389.59
# 2023/Jun     41348.22
# 2023/Jul     41195.41
# 2023/Ago     40113.37
# Total      6789884.11
# Length: 188, dtype: float64

# %%
dados2 = pd.read_csv("/ARQUIVO SUS DATA DE PROCESSAMENTO.csv", encoding="ISO 8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",", usecols=[188])
# Out:
# <ipython-input-13-53e41ac9d767>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados2 = pd.read_csv("/ARQUIVO SUS DATA DE PROCESSAMENTO.csv", encoding="ISO 8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",", usecols=[188])

# %%
dados2.head()
# Out:
#    2023/Ago
# 0      8737
# 1      5051
# 2     18070
# 3      4124
# 4     33967
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_0, *['2023/Ago'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
dados["2023/Ago"]
# Out:
# 0       8737
# 1       5051
# 2      18070
# 3       4124
# 4      33967
# 5       4011
# 6        787
# 7      31047
# 8      17989
# 9      36765
# 10     18046
# 11     20260
# 12     53462
# 13      8876
# 14     10108
# 15     74739
# 16    120794
# 17     23441
# 18     71133
# 19    231599
# 20     82846
# 21     50253
# 22     68685
# 23     17592
# 24     16310
# 25     32249
# 26     22120
# Name: 2023/Ago, dtype: int64

# %%
dados.plot(x="Unidade da Federação", y="2023/Ago")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.ticker as ticker

axis = dados.plot(x="Unidade da Federação", y="2023/Ago", kind="bar", figsize=(25,15))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.2f}"))
plt.title("VALOR POR UNIDADE DA FEDERAÇÃO")
plt.xticks(rotation=45)
plt.show()
